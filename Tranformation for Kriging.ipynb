# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./income_final.csv', encoding='utf8')

# %%
df
# Out:
#       Unnamed: 0 State_Name State_ab        Lat        Lon    Mean  Median  \
# 0          18841   New York       NY  43.810218 -76.022978   54499   37697
# 1          18843   New York       NY  41.848203 -73.555575   82188   56048
# 2          18844   New York       NY  42.070565 -76.162636   73219   54363
# 3          18845   New York       NY  40.588013 -73.729360  131519  114157
# 4          18846   New York       NY  42.301697 -75.478883   52841   44096
# 5          18847   New York       NY  40.606348 -73.645982  110516   91529
# 6          18848   New York       NY  41.447173 -74.118707  100299  102874
# 7          18850   New York       NY  41.068236 -73.954937  123435  115560
# 8          18851   New York       NY  43.480862 -75.329636   48744   30120
# 9          18852   New York       NY  43.149446 -75.985310   56966  300000
# 10         18853   New York       NY  40.939444 -73.826446  166618  188499
# ...

# %%
df['logMean'] = df.apply(lambda row: np.log10(row['Mean']), axis=1)
# Out:
# /Users/damaderu/Documents/programming/ML/anaconda/envs/ds/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       Unnamed: 0 State_Name State_ab        Lat        Lon    Mean  Median  \
# 0          18841   New York       NY  43.810218 -76.022978   54499   37697
# 1          18843   New York       NY  41.848203 -73.555575   82188   56048
# 2          18844   New York       NY  42.070565 -76.162636   73219   54363
# 3          18845   New York       NY  40.588013 -73.729360  131519  114157
# 4          18846   New York       NY  42.301697 -75.478883   52841   44096
# 5          18847   New York       NY  40.606348 -73.645982  110516   91529
# 6          18848   New York       NY  41.447173 -74.118707  100299  102874
# 7          18850   New York       NY  41.068236 -73.954937  123435  115560
# 8          18851   New York       NY  43.480862 -75.329636   48744   30120
# 9          18852   New York       NY  43.149446 -75.985310   56966  300000
# 10         18853   New York       NY  40.939444 -73.826446  166618  188499
# ...

# %%
df.replace(-np.inf, -1000)
# Out:
#       Unnamed: 0 State_Name State_ab        Lat        Lon    Mean  Median  \
# 0          18841   New York       NY  43.810218 -76.022978   54499   37697
# 1          18843   New York       NY  41.848203 -73.555575   82188   56048
# 2          18844   New York       NY  42.070565 -76.162636   73219   54363
# 3          18845   New York       NY  40.588013 -73.729360  131519  114157
# 4          18846   New York       NY  42.301697 -75.478883   52841   44096
# 5          18847   New York       NY  40.606348 -73.645982  110516   91529
# 6          18848   New York       NY  41.447173 -74.118707  100299  102874
# 7          18850   New York       NY  41.068236 -73.954937  123435  115560
# 8          18851   New York       NY  43.480862 -75.329636   48744   30120
# 9          18852   New York       NY  43.149446 -75.985310   56966  300000
# 10         18853   New York       NY  40.939444 -73.826446  166618  188499
# ...

# %%
df.to_csv('income_final_log.csv')

# %%
logMean = df[['logMean']]

# %%
import pandas_profiling

# %%
profile = pandas_profiling.ProfileReport(logMean)

# %%
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
import matplotlib.pyplot as plt
import scipy
import scipy.stats

# %%
size = len(logMean.index)

# %%
y = logMean['logMean'].tolist()

# %%
y
# Out:
# [4.736388533497444,
#  4.914808412257522,
#  4.864623793140874,
#  5.1189884980660105,
#  4.722971027912445,
#  5.043425157737735,
#  5.001296603043879,
#  5.091438321379873,
#  4.687921165116413,
#  4.7556157255315235,
#  5.2217219171091935,
#  4.695236441024211,
#  4.756643714037074,
#  4.796012022802761,
#  5.0156530985354655,
#  5.1591609800845974,
#  4.897385138370666,
#  4.754325397016405,
#  4.726800535862888,
#  4.945064631478948,
#  4.910106570925038,
#  4.847282621396443,
#  4.900956713231088,
#  4.934351978406932,
#  4.756803404891328,
#  4.831306553345523,
#  4.971878617026266,
#  5.038707568328147,
#  4.742787954172146,
#  4.989258436747493,
#  4.892823382887621,
#  5.025039470924913,
#  4.732361588669807,
#  5.133679392684302,
#  5.074794506026523,
#  4.785948797329788,
#  4.652188302228009,
#  4.685060660904496,
#  5.011849452647841,
#  4.695385350500007,
#  4.623476718424375,
#  5.1490096151500095,
#  5.073828284401109,
#  5.078931454898691,
#  4.722765506986236,
# ...

# %%
min(y)
# Out:
# -inf

# %%
num_bins = 20
# the histogram of the data
n, bins, patches = plt.hist(y, num_bins, normed=1, facecolor='blue', alpha=0.5)
# Out:
# /Users/damaderu/Documents/programming/ML/anaconda/envs/ds/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-dd7f4cc0b72e> in <module>()
#       1 num_bins = 20
#       2 # the histogram of the data
# ----> 3 n, bins, patches = plt.hist(y, num_bins, normed=1, facecolor='blue', alpha=0.5)
#
# ~/Documents/programming/ML/anaconda/envs/ds/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3130                       histtype=histtype, align=align, orientation=orientation,
# ...

# %%
np.argwhere(np.isnan(y))

# %%
nanlist=[]
for ii in range(len(y)):
    if np.isnan(y[ii]):
        nanlist.append(ii)

# %%
nanlist
